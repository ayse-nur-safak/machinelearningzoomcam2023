# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv'

# !wget $data
# Out:
# --2023-09-18 15:27:59--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: ‘housing.csv.3’
#
# housing.csv.3       100%[===================>]   1.36M  7.31MB/s    in 0.2s
#
# 2023-09-18 15:28:01 (7.31 MB/s) - ‘housing.csv.3’ saved [1423529/1423529]

# %%
df=pd.read_csv('housing.csv.2')

# %%
df1 = pd.DataFrame(df)
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df1.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df1["ocean_proximity"].unique()
df1["ocean_proximity_num"]=df['ocean_proximity'].replace({"NEAR BAY":1,"<1H OCEAN":2,"INLAND":3,"NEAR OCEAN":4,"ISLAND":5})

# %%
df1.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
new_data=df1.loc[df1["ocean_proximity"]=="NEAR BAY"]
new_data.describe()
# Out:
#          longitude     latitude  housing_median_age   total_rooms  \
# count  2290.000000  2290.000000         2290.000000   2290.000000
# mean   -122.260694    37.801057           37.730131   2493.589520
# std       0.147004     0.185434           13.070385   1830.817022
# min    -122.590000    37.350000            2.000000      8.000000
# 25%    -122.410000    37.730000           29.000000   1431.250000
# 50%    -122.250000    37.790000           39.000000   2083.000000
# 75%    -122.140000    37.907500           52.000000   3029.750000
# max    -122.010000    38.340000           52.000000  18634.000000
#
#        total_bedrooms   population   households  median_income  \
# count     2270.000000  2290.000000  2290.000000    2290.000000
# mean       514.182819  1230.317467   488.616157       4.172885
# std        367.887605   885.899035   350.598369       2.017427
# min          1.000000     8.000000     1.000000       0.499900
# ...

# %%
bedroom_mean = round(df1['total_bedrooms'].mean())
bedroom_mean
df1['total_bedrooms'].fillna(bedroom_mean, inplace=True)
df1.isnull().sum()

meanbefore = round(df1['total_bedrooms'].mean())
df1['total_bedrooms_filled'] = df1['total_bedrooms'].fillna(meanbefore)
meanafter = round(df['total_bedrooms_filled'].mean())

print(f"Mean  before ({meanbefore}) and Mean after ({meanafter}) are equal?: {meanbefore == meanafter}")
# Out:
# Mean  before (538) and Mean after (538) are equal?: True

# %%
# Out:
#        housing_median_age  total_rooms  total_bedrooms
# 0                    41.0        880.0           129.0
# 1                    21.0       7099.0          1106.0
# 2                    52.0       1467.0           190.0
# 3                    52.0       1274.0           235.0
# 4                    52.0       1627.0           280.0
# ...                   ...          ...             ...
# 20635                25.0       1665.0           374.0
# 20636                18.0        697.0           150.0
# 20637                17.0       2254.0           485.0
# 20638                18.0       1860.0           409.0
# 20639                16.0       2785.0           616.0
#
# [20640 rows x 3 columns]

# %%
b= df1[df1["ocean_proximity"]=="ISLAND"]
b=b[[
 'housing_median_age',
 'total_rooms',
 'total_bedrooms']]
b.drop_duplicates(inplace=True)
X = b.values
XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)
y = np.array([950, 1300, 800, 1000, 1300])
XTXiXT = XTX_inv.dot(X.T)
w = XTXiXT.dot(y)
print(f"The w vector is: {w}")
print(f"[ANSWER-7] The first element of w is: {w[2]}")
# Out:
# The w vector is: [23.12330961 -1.48124183  5.69922946]
# [ANSWER-7] The first element of w is: 5.699229455065586
